# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
project_directory = '/content/drive/MyDrive/python demo'

# %% [markdown]
# ## **Importing librarys**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pandas.core.arrays.interval import NA

# %% [markdown]
# ## **loading dataset**

# %%
df=pd.read_csv(project_directory+'/carbon emission/carbon emmision dataset.csv')
# Out:
# <ipython-input-4-bc10f51f69a2>:1: DtypeWarning: Columns (6,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(project_directory+'/carbon emission/carbon emmision dataset.csv')

# %%
df
# Out:
#                                         file  year manufacturer  \
# 0                     DatapartC_july2000.csv  2000   Alfa Romeo
# 1                     DatapartC_july2000.csv  2000   Alfa Romeo
# 2                     DatapartC_july2000.csv  2000   Alfa Romeo
# 3                     DatapartC_july2000.csv  2000   Alfa Romeo
# 4                     DatapartC_july2000.csv  2000   Alfa Romeo
# ...                                      ...   ...          ...
# 45506  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45507  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45508  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45509  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45510  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
#
#                model                       description  euro_standard  \
# 0          145 Range                1.6 Twin Spark 16v              2
# ...

# %%
df.head()
# Out:
#                      file  year manufacturer      model         description  \
# 0  DatapartC_july2000.csv  2000   Alfa Romeo  145 Range  1.6 Twin Spark 16v
# 1  DatapartC_july2000.csv  2000   Alfa Romeo  145 Range  1.8 Twin Spark 16v
# 2  DatapartC_july2000.csv  2000   Alfa Romeo  145 Range          Cloverleaf
# 3  DatapartC_july2000.csv  2000   Alfa Romeo  146 Range  1.6 Twin Spark 16v
# 4  DatapartC_july2000.csv  2000   Alfa Romeo  146 Range  1.8 Twin Spark 16v
#
#    euro_standard tax_band transmission transmission_type  engine_capacity  \
# 0              2      NaN           M5            Manual           1598.0
# 1              2      NaN           M5            Manual           1747.0
# 2              2      NaN           M5            Manual           1970.0
# 3              2      NaN           M5            Manual           1598.0
# 4              2      NaN           M5            Manual           1747.0
#
# ...

# %%
df.tail()
# Out:
#                                         file  year manufacturer  \
# 45506  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45507  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45508  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45509  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
# 45510  download-data-for-Aug-2013-Euro-6.csv  2013   Volkswagen
#
#                model                       description  euro_standard  \
# 45506  New Golf 2013          2.0 TDI 184PS 5 door DSG              6
# 45507  New Golf 2013      GTI 2.0 TSI 220PS 3 / 5 door              6
# 45508  New Golf 2013      GTI 2.0 TSI 230PS 3 / 5 door              6
# 45509  New Golf 2013  GTI 2.0 TSI 220PS 3 / 5 door DSG              6
# 45510  New Golf 2013  GTI 2.0 TSI 230PS 3 / 5 door DSG              6
#
#       tax_band transmission transmission_type  engine_capacity  ...  \
# 45506        D           D6               NaN           1968.0  ...
# ...

# %% [markdown]
# # **Data Manupulation and Exploring**

# %%
df.isna().sum()
# Out:
# file                          0
# year                          0
# manufacturer                  0
# model                         0
# description                   0
# euro_standard                 0
# tax_band                  37674
# transmission                 10
# transmission_type           341
# engine_capacity               7
# fuel_type                     0
# urban_metric                 13
# extra_urban_metric           13
# combined_metric               7
# urban_imperial               13
# extra_urban_imperial         13
# combined_imperial             7
# noise_level                   9
# co2                           0
# thc_emissions             22321
# co_emissions                319
# nox_emissions              5361
# thc_nox_emissions         40081
# particulates_emissions    30710
# fuel_cost_12000_miles     12375
# fuel_cost_6000_miles      33311
# standard_12_months        41994
# standard_6_months         42585
# first_year_12_months      41994
# ...

# %%
df.isnull()
# Out:
#         file   year  manufacturer  model  description  euro_standard  \
# 0      False  False         False  False        False          False
# 1      False  False         False  False        False          False
# 2      False  False         False  False        False          False
# 3      False  False         False  False        False          False
# 4      False  False         False  False        False          False
# ...      ...    ...           ...    ...          ...            ...
# 45506  False  False         False  False        False          False
# 45507  False  False         False  False        False          False
# 45508  False  False         False  False        False          False
# 45509  False  False         False  False        False          False
# 45510  False  False         False  False        False          False
#
#        tax_band  transmission  transmission_type  engine_capacity  ...  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45511 entries, 0 to 45510
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   file                    45511 non-null  object
#  1   year                    45511 non-null  int64
#  2   manufacturer            45511 non-null  object
#  3   model                   45511 non-null  object
#  4   description             45511 non-null  object
#  5   euro_standard           45511 non-null  int64
#  6   tax_band                7837 non-null   object
#  7   transmission            45501 non-null  object
#  8   transmission_type       45170 non-null  object
#  9   engine_capacity         45504 non-null  float64
#  10  fuel_type               45511 non-null  object
#  11  urban_metric            45498 non-null  float64
#  12  extra_urban_metric      45498 non-null  float64
#  13  combined_metric         45504 non-null  float64
# ...

# %%
unique_values_manufacturer=df["manufacturer"].unique()
print(unique_values_manufacturer)
# Out:
# ['Alfa Romeo' 'Aston Martin Lagonda' 'Audi' 'BMW' 'Cadillac' 'Chevrolet'
#  'Chrysler Jeep' 'Citroen' 'Daewoo Cars' 'Daihatsu' 'Ferrari' 'Fiat'
#  'Ford' 'Honda' 'Hyundai' 'Isuzu' 'Jaguar Cars' 'Kia' 'Lamborghini'
#  'Land Rover' 'Lexus' 'Lotus' 'LTI' 'Maserati' 'Mazda' 'Mercedes-Benz'
#  'Metrocab' 'Micro Compact Car' 'Mitsubishi' 'Nissan' 'Perodua' 'Peugeot'
#  'Porsche' 'Proton' 'Renault' 'Rolls-Royce' 'Rover Group Limited' 'Saab'
#  'Seat' 'Skoda' 'Subaru' 'Suzuki' 'Tata' 'Toyota' 'Vauxhall' 'Volkswagen'
#  'Volvo' 'MG Rover Group' 'Mini' 'Morgan Motor Company' 'Bentley Motors'
#  'Smart' 'SsangYong' 'Corvette' 'Dodge' 'Hummer' 'Abarth' 'Infiniti'
#  'MG Motors Uk' 'McLaren' 'Dacia' 'MG Motors UK']

# %%
df.describe()
# Out:
#                year  euro_standard  engine_capacity  urban_metric  \
# count  45511.000000   45511.000000     45504.000000  45498.000000
# mean    2007.316055       3.969282      2182.770526     10.472676
# std        3.832559       0.838025       899.100669      3.984944
# min     2000.000000       2.000000       209.000000      3.100000
# 25%     2004.000000       3.000000      1598.000000      7.700000
# 50%     2008.000000       4.000000      1988.000000      9.800000
# 75%     2011.000000       5.000000      2429.000000     12.400000
# max     2013.000000       6.000000      8285.000000     41.200000
#
#        extra_urban_metric  combined_metric  urban_imperial  \
# count        45498.000000     45504.000000    45498.000000
# mean             6.139602         7.721963       30.527557
# std              1.783382         2.503880       10.623745
# min              2.900000         1.200000        6.800000
# 25%              4.900000         5.900000       22.800000
# ...

# %%
df.corr()
# Out:
# <ipython-input-14-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                             year  euro_standard  engine_capacity  \
# year                    1.000000       0.873260        -0.025921
# euro_standard           0.873260       1.000000        -0.041140
# engine_capacity        -0.025921      -0.041140         1.000000
# urban_metric           -0.315768      -0.296510         0.776723
# extra_urban_metric     -0.291298      -0.283847         0.698636
# combined_metric        -0.314146      -0.299056         0.766905
# urban_imperial          0.390009       0.362021        -0.593433
# extra_urban_imperial    0.347449       0.329183        -0.623380
# combined_imperial       0.370371       0.345979        -0.612094
# ...

# %%
unique_values=df["year"].unique()
print(unique_values)
# Out:
# [2000 2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013]

# %%
unique_values_manufcont=df["manufacturer"].nunique()
print(unique_values_manufcont)
# Out:
# 62

# %%
#deleted the first columns name file
df=df.drop(['file'],axis=1)

# %%
df
# Out:
#        year manufacturer          model                       description  \
# 0      2000   Alfa Romeo      145 Range                1.6 Twin Spark 16v
# 1      2000   Alfa Romeo      145 Range                1.8 Twin Spark 16v
# 2      2000   Alfa Romeo      145 Range                        Cloverleaf
# 3      2000   Alfa Romeo      146 Range                1.6 Twin Spark 16v
# 4      2000   Alfa Romeo      146 Range                1.8 Twin Spark 16v
# ...     ...          ...            ...                               ...
# 45506  2013   Volkswagen  New Golf 2013          2.0 TDI 184PS 5 door DSG
# 45507  2013   Volkswagen  New Golf 2013      GTI 2.0 TSI 220PS 3 / 5 door
# 45508  2013   Volkswagen  New Golf 2013      GTI 2.0 TSI 230PS 3 / 5 door
# 45509  2013   Volkswagen  New Golf 2013  GTI 2.0 TSI 220PS 3 / 5 door DSG
# 45510  2013   Volkswagen  New Golf 2013  GTI 2.0 TSI 230PS 3 / 5 door DSG
#
#        euro_standard tax_band transmission transmission_type  engine_capacity  \
# ...

# %% [markdown]
# ## **Deleting the unwanted columns from the main dataframe**

# %%
#deleted the column name 'urban_metric' ,'extra_urban_metric','combined_metric' , 'urban_imperial' , 'extra_urban_imperial',  'combined_imperial'
df_cleaned=df.drop(['tax_band' ,'fuel_cost_12000_miles','fuel_cost_6000_miles','standard_12_months','standard_6_months','first_year_12_months','first_year_6_months','date_of_change','urban_metric' ,'extra_urban_metric','combined_metric' , 'urban_imperial' , 'extra_urban_imperial',  'combined_imperial'],axis=1)  
df_cleaned
# Out:
#        year manufacturer          model                       description  \
# 0      2000   Alfa Romeo      145 Range                1.6 Twin Spark 16v
# 1      2000   Alfa Romeo      145 Range                1.8 Twin Spark 16v
# 2      2000   Alfa Romeo      145 Range                        Cloverleaf
# 3      2000   Alfa Romeo      146 Range                1.6 Twin Spark 16v
# 4      2000   Alfa Romeo      146 Range                1.8 Twin Spark 16v
# ...     ...          ...            ...                               ...
# 45506  2013   Volkswagen  New Golf 2013          2.0 TDI 184PS 5 door DSG
# 45507  2013   Volkswagen  New Golf 2013      GTI 2.0 TSI 220PS 3 / 5 door
# 45508  2013   Volkswagen  New Golf 2013      GTI 2.0 TSI 230PS 3 / 5 door
# 45509  2013   Volkswagen  New Golf 2013  GTI 2.0 TSI 220PS 3 / 5 door DSG
# 45510  2013   Volkswagen  New Golf 2013  GTI 2.0 TSI 230PS 3 / 5 door DSG
#
#        euro_standard transmission transmission_type  engine_capacity  \
# ...

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45511 entries, 0 to 45510
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    45511 non-null  int64
#  1   manufacturer            45511 non-null  object
#  2   model                   45511 non-null  object
#  3   description             45511 non-null  object
#  4   euro_standard           45511 non-null  int64
#  5   transmission            45501 non-null  object
#  6   transmission_type       45170 non-null  object
#  7   engine_capacity         45504 non-null  float64
#  8   fuel_type               45511 non-null  object
#  9   noise_level             45502 non-null  float64
#  10  co2                     45511 non-null  int64
#  11  thc_emissions           23190 non-null  float64
#  12  co_emissions            45192 non-null  float64
#  13  nox_emissions           40150 non-null  float64
# ...

# %% [markdown]
# ### **Creating new segments based on the engine cc inside the df_cleaned**

# %%
from pandas.core.arrays.interval import NA
#categorizing the cars based on engine cc
engine_capacity_new=df_cleaned['engine_capacity']
my_array_clean = engine_capacity_new[~np.isnan(engine_capacity_new)]
bins=[0,1000,1500,2000,8500]
labels=['microcars','compact cars','mid-size cars','large cars']
df_cleaned['group1']=pd.cut(my_array_clean,bins=bins,labels=labels)
print(df_cleaned['group1'])
# Out:
# 0        mid-size cars
# 1        mid-size cars
# 2        mid-size cars
# 3        mid-size cars
# 4        mid-size cars
#              ...
# 45506    mid-size cars
# 45507    mid-size cars
# 45508    mid-size cars
# 45509    mid-size cars
# 45510    mid-size cars
# Name: group1, Length: 45511, dtype: category
# Categories (4, object): ['microcars' < 'compact cars' < 'mid-size cars' < 'large cars']

# %%
print(df_cleaned['group1'].nunique())
df_cleaned['group1'].unique()
# Out:
# 4
# ['mid-size cars', 'large cars', 'compact cars', 'microcars', NaN]
# Categories (4, object): ['microcars' < 'compact cars' < 'mid-size cars' < 'large cars']

# %%
type(df_cleaned)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df_cleaned["group1"])
# Out:
# pandas.core.series.Series

# %%
df_cleaned["group1"].shape
# Out:
# (45511,)

# %%
list(df_cleaned.select_dtypes(['object']).columns)
# Out:
# ['manufacturer',
#  'model',
#  'description',
#  'transmission',
#  'transmission_type',
#  'fuel_type']

# %%
df_cleaned.select_dtypes(['object']).columns
# Out:
# Index(['manufacturer', 'model', 'description', 'transmission',
#        'transmission_type', 'fuel_type'],
#       dtype='object')

# %% [markdown]
# ## **Converting the object to category**

# %%
#converting object to category
df_cleaned.loc[:,df_cleaned.dtypes == 'object'] = df_cleaned.loc[:,df_cleaned.dtypes =='object'].astype('category')
# Out:
# <ipython-input-28-4669f4e66a0d>:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_cleaned.loc[:,df_cleaned.dtypes == 'object'] = df_cleaned.loc[:,df_cleaned.dtypes =='object'].astype('category')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45511 entries, 0 to 45510
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    45511 non-null  int64
#  1   manufacturer            45511 non-null  category
#  2   model                   45511 non-null  category
#  3   description             45511 non-null  category
#  4   euro_standard           45511 non-null  int64
#  5   transmission            45501 non-null  category
#  6   transmission_type       45170 non-null  category
#  7   engine_capacity         45504 non-null  float64
#  8   fuel_type               45511 non-null  category
#  9   noise_level             45502 non-null  float64
#  10  co2                     45511 non-null  int64
#  11  thc_emissions           23190 non-null  float64
#  12  co_emissions            45192 non-null  float64
#  13  nox_emissions           40150 non-null  float64
# ...

# %% [markdown]
# ## **Creating a subset of values based on co_emission with group1**

# %%
#creating subset of values based on co_emission and group1(which is the categorical of engine capacity)
emis_grp=df_cleaned[["co_emissions","group1","transmission_type"]]
emis_grp.head(10)
# Out:
#    co_emissions         group1 transmission_type
# 0         980.0  mid-size cars            Manual
# 1        1105.0  mid-size cars            Manual
# 2        1103.0  mid-size cars            Manual
# 3         980.0  mid-size cars            Manual
# 4        1105.0  mid-size cars            Manual
# 5        1103.0  mid-size cars            Manual
# 6         919.0  mid-size cars            Manual
# 7        1069.0  mid-size cars            Manual
# 8        1078.0  mid-size cars         Automatic
# 9        1078.0  mid-size cars            Manual

# %%
#car manufactures with manual transmission 
manual=df_cleaned[df_cleaned.transmission_type == 'Manual']
manual
#car manufacturers with manual and petrol cars 
manual_gas=df_cleaned[(df_cleaned.transmission_type == 'Manual') & (df_cleaned.fuel_type == 'Petrol')]
manual_gas
# Out:
#        year manufacturer                 model         description  \
# 0      2000   Alfa Romeo             145 Range  1.6 Twin Spark 16v
# 1      2000   Alfa Romeo             145 Range  1.8 Twin Spark 16v
# 2      2000   Alfa Romeo             145 Range          Cloverleaf
# 3      2000   Alfa Romeo             146 Range  1.6 Twin Spark 16v
# 4      2000   Alfa Romeo             146 Range  1.8 Twin Spark 16v
# ...     ...          ...                   ...                 ...
# 45088  2013        Volvo  V60, Model Year 2013           T4 Manual
# 45090  2013        Volvo  V60, Model Year 2013           T5 Manual
# 45101  2013        Volvo  V60, Model Year 2014                  T3
# 45111  2013        Volvo  V70, Model Year 2012           T4 Manual
# 45113  2013        Volvo  V70, Model Year 2012           T5 Manual
#
#        euro_standard transmission transmission_type  engine_capacity  \
# 0                  2           M5            Manual           1598.0
# ...

# %% [markdown]
# # ***Cleaning the remaining missing values***

# %%
#cleaned one 
new1_df=df_cleaned.drop(["particulates_emissions","thc_nox_emissions",'thc_emissions'],axis=1)
new1_df
new1_df.isna().sum()
# Out:
# year                    0
# manufacturer            0
# model                   0
# description             0
# euro_standard           0
# transmission           10
# transmission_type     341
# engine_capacity         7
# fuel_type               0
# noise_level             9
# co2                     0
# co_emissions          319
# nox_emissions        5361
# group1                  7
# dtype: int64

# %%
mean = new1_df["nox_emissions"].mean()
median = new1_df["nox_emissions"].median()
group = new1_df.groupby("engine_capacity")
print(mean)
print(median)
print(group.mean())
print(group.median())
# Out:
# 127.16438692403486
# 56.0
#                         year  euro_standard  noise_level         co2  \
# engine_capacity
# 209.0            2013.000000       6.000000    73.000000  209.000000
# 599.0            2002.674419       2.883721    71.825581  120.302326
# 658.0            2009.000000       4.000000    73.800000  114.000000
# 660.0            2004.666667       3.333333    71.600000  151.000000
# 698.0            2005.386667       4.000000    73.760000  120.206667
# ...                      ...            ...          ...         ...
# 6752.0           2012.000000       5.000000    72.000000  393.000000
# 6761.0           2005.103448       3.517241    71.277586  465.672414
# 7011.0           2009.285714       4.285714    74.000000  342.857143
# 7990.0           2000.500000       2.000000    74.600000  483.000000
# 8285.0           2007.500000       3.750000    75.000000  488.000000
#
#                  co_emissions  nox_emissions
# engine_capacity
# ...

# %%
#adding the mean value to the na of co_emission value using impute method
new1_df['nox_emissions'] = group['nox_emissions'].fillna(group['nox_emissions'].transform('mean'))
new1_df
# Out:
#        year manufacturer          model                       description  \
# 0      2000   Alfa Romeo      145 Range                1.6 Twin Spark 16v
# 1      2000   Alfa Romeo      145 Range                1.8 Twin Spark 16v
# 2      2000   Alfa Romeo      145 Range                        Cloverleaf
# 3      2000   Alfa Romeo      146 Range                1.6 Twin Spark 16v
# 4      2000   Alfa Romeo      146 Range                1.8 Twin Spark 16v
# ...     ...          ...            ...                               ...
# 45506  2013   Volkswagen  New Golf 2013          2.0 TDI 184PS 5 door DSG
# 45507  2013   Volkswagen  New Golf 2013      GTI 2.0 TSI 220PS 3 / 5 door
# 45508  2013   Volkswagen  New Golf 2013      GTI 2.0 TSI 230PS 3 / 5 door
# 45509  2013   Volkswagen  New Golf 2013  GTI 2.0 TSI 220PS 3 / 5 door DSG
# 45510  2013   Volkswagen  New Golf 2013  GTI 2.0 TSI 230PS 3 / 5 door DSG
#
#        euro_standard transmission transmission_type  engine_capacity  \
# ...

# %%
new1_df.isna().sum()
# Out:
# year                   0
# manufacturer           0
# model                  0
# description            0
# euro_standard          0
# transmission          10
# transmission_type    341
# engine_capacity        7
# fuel_type              0
# noise_level            9
# co2                    0
# co_emissions         319
# nox_emissions        160
# group1                 7
# dtype: int64

# %%
new1_df=new1_df.dropna()
print(new1_df.isna().sum())
new1_df.shape
# Out:
# year                 0
# manufacturer         0
# model                0
# description          0
# euro_standard        0
# transmission         0
# transmission_type    0
# engine_capacity      0
# fuel_type            0
# noise_level          0
# co2                  0
# co_emissions         0
# nox_emissions        0
# group1               0
# dtype: int64
# (44696, 14)

# %%
new1_df
# Out:
#        year manufacturer                  model         description  \
# 0      2000   Alfa Romeo              145 Range  1.6 Twin Spark 16v
# 1      2000   Alfa Romeo              145 Range  1.8 Twin Spark 16v
# 2      2000   Alfa Romeo              145 Range          Cloverleaf
# 3      2000   Alfa Romeo              146 Range  1.6 Twin Spark 16v
# 4      2000   Alfa Romeo              146 Range  1.8 Twin Spark 16v
# ...     ...          ...                    ...                 ...
# 45173  2013        Volvo  XC70, Model Year 2014              D5 AWD
# 45174  2013        Volvo  XC70, Model Year 2014              T6 AWD
# 45175  2013        Volvo  XC90, Model Year 2012         D5 AWD Auto
# 45176  2013        Volvo  XC90, Model Year 2013                  D5
# 45177  2013        Volvo  XC90, Model Year 2014                  D5
#
#        euro_standard transmission transmission_type  engine_capacity  \
# 0                  2           M5            Manual           1598.0
# ...

# %%
#grouping co2,co emission with transmittion type based on counting
df_cleaned.groupby(["co2","co_emissions"])["transmission_type"].count()
# Out:
# co2  co_emissions
# 27   178.0           3
#      184.0           0
# 48   20.0            0
# 49   118.0           0
# 79   197.0           4
#                     ..
# 570  160.0           2
#      200.0           2
# 575  430.0           6
#      950.0           4
# 590  1020.0          2
# Name: transmission_type, Length: 14096, dtype: int64

# %%
group = df_cleaned.groupby(["co2","co_emissions"]).count()
group["transmission_type"]
# Out:
# co2  co_emissions
# 27   178.0           3
#      184.0           0
# 48   20.0            0
# 49   118.0           0
# 79   197.0           4
#                     ..
# 570  160.0           2
#      200.0           2
# 575  430.0           6
#      950.0           4
# 590  1020.0          2
# Name: transmission_type, Length: 14096, dtype: int64

# %% [markdown]
# # **Data Analysis and visualization**

# %% [markdown]
# ### *data showing the car brand names in uk*

# %%
#Frequency distribution of feature : manufacturer
plt.figure(figsize=(19,5)); 
new1_df.groupby("manufacturer")["manufacturer"].count().sort_values(ascending=False).plot(kind="bar") 
plt.title("Frequency distribution of  manufacturer", fontsize=20) 
plt.ylabel("Frequency", fontsize=15) 
plt.xlabel("Brand Name", fontsize=15) 
plt.xticks(rotation=90) 
plt.tight_layout() 
plt.show()

# %% [markdown]
# ### *created a plot showing the changes in the co2 emission over the years, within different car segments.*

# %%
sns.relplot(
    data= new1_df, kind="line",
    x="year", y="co2", col="transmission_type",
    hue="group1",#style="fuel_type",
    facet_kws=dict(sharex=False),
)

# %%
df_cleaned.shape
# Out:
# (45511, 17)

# %% [markdown]
# ### *Created a top 20 cars manufactures based on co2 emissions.*

# %%
#top 20 manufactures based on co2 emissions
grouped = new1_df.groupby('manufacturer')['co2'].mean().sort_values(ascending=False)[:20]
plt.style.use('bmh')
plt.figure(figsize=(19,5));
grouped.plot(kind="bar")
plt.title("Top 20 car manufactures who produced the co2 emission", fontsize=20) 
plt.ylabel("Frequency", fontsize=15) 
plt.xlabel("Car manufacture", fontsize=15) 
plt.axhline(new1_df["co2"].mean(),color='r',linestyle='dashed',linewidth=2)
plt.axhline(new1_df["co2"].median(),color='g',linestyle='dashed',linewidth=2)
plt.xticks(rotation=90) 
plt.tight_layout() 
plt.show()

# %%
fig, ax = plt.subplots(figsize = (5, 5))
sns.countplot(data = new1_df, x = 'group1')
ax.set_title('Segments based on engine cc')
plt.xlabel("")
plt.xticks(rotation=90)
fig.show()

# %%
#co_emission
sns.displot(data=new1_df, x="co_emissions", col="transmission_type", kde=True)
plt.show()

# %%
#plot showing count of co_emissions in each category
sns.displot(data=new1_df, x="co_emissions", hue="transmission_type", col="group1")
plt.show()

# %%
  
import pandas as pd
# Group the dataset by fuel type and calculate the mean emissions for each type
fuel_emissions = new1_df.groupby('fuel_type')['co2','co_emissions', 'nox_emissions'].mean()

# Print the mean emissions for each fuel type
print(fuel_emissions)
fuel_emissions.plot(kind='bar')
plt.xlabel('Fuel Type')
plt.ylabel('Emissions')
plt.title('Mean Emissions by Fuel Type')
plt.show()
# Out:
# <ipython-input-69-be5f3aa19dd2>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   fuel_emissions = new1_df.groupby('fuel_type')['co2','co_emissions', 'nox_emissions'].mean()
#                                  co2  co_emissions  nox_emissions
# fuel_type
# CNG                       172.209677    464.225806      90.838710
# Diesel                    164.628618    201.428776     131.164545
# Diesel Electric           105.136364    228.818182     126.954545
# Electricity                      NaN           NaN            NaN
# Electricity/Diesel               NaN           NaN            NaN
# Electricity/Petrol         27.000000    178.000000      32.000000
# LPG                       180.445205    583.856164     105.643375
# LPG / Petrol              167.076923    677.307692      66.505629
# Petrol                    205.859297    460.744489     117.236324
# ...

# %%
# Group the data by segment and manufacturer, and calculate the mean CO2 emissions
grouped_data_co = new1_df.groupby(['group1', 'manufacturer'])['co_emissions'].mean()

# Sort the data by segment and emissions in descending order
sorted_data_co = grouped_data_co.reset_index().sort_values(['group1','co_emissions'], ascending=[True, False])

# Select the highest emissions for each segment and manufacturer
highest_emissions_co = sorted_data_co.groupby('group1').head(1)

# Print the results
print(highest_emissions_co)
plt.bar(highest_emissions_co['group1'].astype(str) + '( '+ highest_emissions_co['manufacturer'].astype(str) + ')' ,highest_emissions_co['co_emissions'], color='b')
plt.title('Highest CO Emissions by Segment and Manufacturer')
plt.xlabel('Segment')
plt.ylabel('CO Emissions')
plt.xticks(rotation=90)
plt.show()
# Out:
#             group1 manufacturer  co_emissions
# 43       microcars      Perodua    721.500000
# 74    compact cars  Daewoo Cars    731.724138
# 136  mid-size cars  Daewoo Cars    888.481013
# 215     large cars        Lotus   1204.470588

# %%
new1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44696 entries, 0 to 45177
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               44696 non-null  int64
#  1   manufacturer       44696 non-null  category
#  2   model              44696 non-null  category
#  3   description        44696 non-null  category
#  4   euro_standard      44696 non-null  int64
#  5   transmission       44696 non-null  category
#  6   transmission_type  44696 non-null  category
#  7   engine_capacity    44696 non-null  float64
#  8   fuel_type          44696 non-null  category
#  9   noise_level        44696 non-null  float64
#  10  co2                44696 non-null  int64
#  11  co_emissions       44696 non-null  float64
#  12  nox_emissions      44696 non-null  float64
#  13  group1             44696 non-null  category
# dtypes: category(7), float64(4), int64(3)
# memory usage: 4.8 MB
